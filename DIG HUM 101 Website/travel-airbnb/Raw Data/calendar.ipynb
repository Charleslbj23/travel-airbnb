# %%
import pandas as pd
df = pd.read_csv('calendar.csv.gz')
df.head()
# Out:
#    listing_id        date available  price  adjusted_price  minimum_nights  \
# 0        2708  2025-12-06         f    NaN             NaN              30
# 1        2708  2025-12-07         f    NaN             NaN              30
# 2        2708  2025-12-08         f    NaN             NaN              30
# 3        2708  2025-12-09         f    NaN             NaN              30
# 4        2708  2025-12-10         f    NaN             NaN              30
#
#    maximum_nights
# 0            1125
# 1            1125
# 2            1125
# 3            1125
# 4            1125
